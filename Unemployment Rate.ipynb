# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("unemployment analysis.csv")
df.head()
# Out:
#                   Country Name Country Code   1991   1992   1993   1994  \
# 0  Africa Eastern and Southern          AFE   7.80   7.84   7.85   7.84
# 1                  Afghanistan          AFG  10.65  10.82  10.72  10.73
# 2   Africa Western and Central          AFW   4.42   4.53   4.55   4.54
# 3                       Angola          AGO   4.21   4.21   4.23   4.16
# 4                      Albania          ALB  10.31  30.01  25.26  20.84
#
#     1995   1996   1997   1998  ...   2012   2013   2014   2015   2016   2017  \
# 0   7.83   7.84   7.86   7.81  ...   6.56   6.45   6.41   6.49   6.61   6.71
# 1  11.18  10.96  10.78  10.80  ...  11.34  11.19  11.14  11.13  11.16  11.18
# 2   4.53   4.57   4.60   4.66  ...   4.64   4.41   4.69   4.63   5.57   6.02
# 3   4.11   4.10   4.09   4.07  ...   7.35   7.37   7.37   7.39   7.41   7.41
# 4  14.61  13.93  16.88  20.05  ...  13.38  15.87  18.05  17.19  15.42  13.62
#
#     2018   2019   2020   2021
# 0   6.73   6.91   7.56   8.11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  235 non-null    object
#  1   Country Code  235 non-null    object
#  2   1991          235 non-null    float64
#  3   1992          235 non-null    float64
#  4   1993          235 non-null    float64
#  5   1994          235 non-null    float64
#  6   1995          235 non-null    float64
#  7   1996          235 non-null    float64
#  8   1997          235 non-null    float64
#  9   1998          235 non-null    float64
#  10  1999          235 non-null    float64
#  11  2000          235 non-null    float64
#  12  2001          235 non-null    float64
#  13  2002          235 non-null    float64
#  14  2003          235 non-null    float64
#  15  2004          235 non-null    float64
#  16  2005          235 non-null    float64
# ...

# %%
df.describe()
# Out:
#              1991        1992        1993        1994        1995        1996  \
# count  235.000000  235.000000  235.000000  235.000000  235.000000  235.000000
# mean     7.278000    7.626340    8.070766    8.246043    8.333915    8.494894
# std      6.013749    6.296617    6.335855    6.243778    6.330822    6.358431
# min      0.300000    0.340000    0.410000    0.470000    0.500000    0.560000
# 25%      2.945000    3.140000    3.700000    3.890000    3.945000    3.995000
# 50%      5.410000    5.710000    6.030000    6.550000    6.700000    7.050000
# 75%      9.815000   10.170000   10.895000   11.110000   11.050000   11.405000
# max     36.120000   36.390000   36.740000   36.980000   37.340000   38.800000
#
#              1997        1998        1999        2000  ...        2012  \
# count  235.000000  235.000000  235.000000  235.000000  ...  235.000000
# mean     8.394043    8.441064    8.568043    8.438979  ...    8.062553
# ...

# %% [markdown]
# ## making sure gaada data yg kosong

# %%
df.isna().sum()
# Out:
# Country Name    0
# Country Code    0
# 1991            0
# 1992            0
# 1993            0
# 1994            0
# 1995            0
# 1996            0
# 1997            0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
df.set_index("Country Name", inplace = True)

# %% [markdown]
# ## perfect!, now let's analyze!

# %%
df_t = df.T
df_t.head()
# Out:
# Country Name Africa Eastern and Southern Afghanistan  \
# Country Code                         AFE         AFG
# 1991                                 7.8       10.65
# 1992                                7.84       10.82
# 1993                                7.85       10.72
# 1994                                7.84       10.73
#
# Country Name Africa Western and Central Angola Albania Arab World  \
# Country Code                        AFW    AGO     ALB        ARB
# 1991                               4.42   4.21   10.31      11.62
# 1992                               4.53   4.21   30.01      12.12
# 1993                               4.55   4.23   25.26      12.86
# 1994                               4.54   4.16   20.84      12.95
#
# Country Name United Arab Emirates Argentina Armenia Australia  ...  \
# Country Code                  ARE       ARG     ARM       AUS  ...
# 1991                         1.87      5.44     1.6      9.58  ...
# ...

# %%
df_deu = df_t["Germany"]
df_deu
# Out:
# Country Code      DEU
# 1991             5.32
# 1992             6.32
# 1993             7.68
# 1994             8.73
# 1995             8.16
# 1996             8.82
# 1997             9.86
# 1998             9.79
# 1999             8.86
# 2000             7.92
# 2001             7.77
# 2002             8.48
# 2003             9.78
# 2004            10.73
# 2005            11.17
# 2006            10.25
# 2007             8.66
# 2008             7.52
# 2009             7.74
# 2010             6.97
# 2011             5.82
# 2012             5.38
# 2013             5.23
# 2014             4.98
# 2015             4.62
# 2016             4.12
# 2017             3.75
# 2018             3.38
# 2019             3.14
# 2020             3.81
# 2021             3.54
# Name: Germany, dtype: object

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 6))

for s in ['top', 'right']:
    ax.spines[s].set_visible(False)

plt.plot(df_deu.iloc[1:])

plt.title("Unemployment Rate in Germany")
plt.xticks(rotation = 60)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate")
plt.grid(axis = "both", ls = "--")

plt.show()

# %%
df_eu = df_t[["Germany","Belgium","France","Netherlands","Spain","Italy"]]
df_eu[1:].head()
# Out:
# Country Name Germany Belgium France Netherlands  Spain  Italy
# 1991            5.32    6.99   9.13        7.28  15.93   10.1
# 1992            6.32     6.7  10.21        5.56   17.7   9.33
# 1993            7.68    8.08  11.32        6.29  22.16  10.24
# 1994            8.73    9.65  12.59        7.16  24.21  11.09
# 1995            8.16    9.34  11.84        7.16  22.67  11.67

# %% [markdown]
# ## Germany compared with another EU Countries

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 6))

for s in ['top', 'right']:
    ax.spines[s].set_visible(False)

plt.plot(df_eu["Germany"].iloc[1:], label = "Germany")
plt.plot(df_eu["Belgium"].iloc[1:], label = "Belgium")
plt.plot(df_eu["France"].iloc[1:], label = "France")
plt.plot(df_eu["Netherlands"].iloc[1:], label = "Netherlands")
plt.plot(df_eu["Spain"].iloc[1:], label = "Spain")
plt.plot(df_eu["Italy"].iloc[1:], label = "Italy")

plt.title("Unemployment Rate European Countries")
plt.xticks(rotation = 60)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate")
plt.grid(axis = "both", ls = "--")

plt.legend(loc = 1)

plt.show()

# %% [markdown]
# ## Country with lowest & highest employment rate

# %%
df_low = df.sort_values(by = "2021")
df_low.head()
# Out:
#                 Country Code  1991  1992  1993  1994  1995  1996  1997  1998  \
# Country Name
# Qatar                    QAT  0.81  0.81  0.81  0.82  0.82  0.83  0.83  0.83
# Cambodia                 KHM  0.73  0.75  0.80  1.33  0.78  0.84  0.91  0.94
# Niger                    NER  1.35  1.35  1.38  1.38  1.39  1.42  1.43  1.41
# Solomon Islands          SLB  1.32  1.25  1.40  1.36  1.36  1.53  1.61  1.59
# Lao PDR                  LAO  2.53  2.51  2.55  2.47  2.60  2.49  2.38  2.42
#
#                  1999  ...  2012  2013  2014  2015  2016  2017  2018  2019  \
# Country Name           ...
# Qatar            0.84  ...  0.48  0.28  0.20  0.17  0.15  0.14  0.11  0.10
# Cambodia         0.90  ...  0.51  0.44  0.69  0.39  0.72  0.14  0.14  0.15
# Niger            1.47  ...  2.18  1.37  0.52  0.53  0.53  0.54  0.55  0.55
# Solomon Islands  1.66  ...  1.05  0.69  0.73  0.73  0.70  0.71  0.72  0.75
# Lao PDR          2.11  ...  0.74  0.75  0.76  0.78  0.79  0.81  0.83  0.85
#
# ...

# %%
df_low.T.iloc[1:,:3].head()
# Out:
# Country Name Qatar Cambodia Niger
# 1991          0.81     0.73  1.35
# 1992          0.81     0.75  1.35
# 1993          0.81      0.8  1.38
# 1994          0.82     1.33  1.38
# 1995          0.82     0.78  1.39

# %%
df_hi = df.sort_values(by = "2021", ascending = False)
df_hi.head()
# Out:
#                    Country Code   1991   1992   1993   1994   1995   1996  \
# Country Name
# South Africa                ZAF  29.95  29.98  29.92  29.89  29.89  29.87
# Djibouti                    DJI  29.36  29.20  29.19  29.02  28.94  28.84
# Eswatini                    SWZ  21.81  21.76  21.73  21.71  21.65  22.08
# West Bank and Gaza          PSE  11.60  11.31  11.29  11.15  11.10  11.03
# Botswana                    BWA  13.82  16.30  18.76  21.20  21.37  21.59
#
#                      1997   1998   1999  ...   2012   2013   2014   2015  \
# Country Name                             ...
# South Africa        29.91  29.95  29.91  ...  24.73  24.56  24.89  25.15
# Djibouti            28.70  28.58  28.43  ...  26.78  26.64  26.48  26.33
# Eswatini            22.50  23.08  23.65  ...  25.15  24.55  23.97  23.33
# West Bank and Gaza  10.83  10.72  10.64  ...  19.20  19.89  20.53  23.00
# Botswana            21.17  20.86  18.29  ...  18.95  19.40  19.99  20.57
#
# ...

# %%
df_hi.T.iloc[1:,:3].head()
# Out:
# Country Name South Africa Djibouti Eswatini
# 1991                29.95    29.36    21.81
# 1992                29.98     29.2    21.76
# 1993                29.92    29.19    21.73
# 1994                29.89    29.02    21.71
# 1995                29.89    28.94    21.65

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 6))

for s in ['top', 'right']:
    ax.spines[s].set_visible(False)
    
plt.plot(df_low.T["Qatar"].iloc[1:], label = "Qatar")
plt.plot(df_low.T["Cambodia"].iloc[1:], label = "Cambodia")
plt.plot(df_low.T["Niger"].iloc[1:], label = "Niger")
plt.plot(df_low.T["South Africa"].iloc[1:], label = "South Africa")
plt.plot(df_low.T["Djibouti"].iloc[1:], label = "Djibouti")
plt.plot(df_low.T["Eswatini"].iloc[1:], label = "Eswatini")
    
plt.title("Countries with the highest and lowest Unemployment Rate")
plt.xticks(rotation = 60)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate")
plt.grid(axis = "both", ls = "--")

plt.legend(loc = 5)

plt.show()

# %%
df.T["Armenia"].iloc[1:]
# Out:
# 1991      1.6
# 1992      1.8
# 1993      5.3
# 1994      6.6
# 1995      6.7
# 1996      9.3
# 1997     10.8
# 1998      9.4
# 1999     11.2
# 2000    11.05
# 2001    10.91
# 2002    10.78
# 2003    10.59
# 2004    10.34
# 2005     10.2
# 2006     10.0
# 2007     9.81
# 2008    14.39
# 2009    18.44
# 2010    19.01
# 2011    18.44
# 2012     17.3
# 2013    16.18
# 2014     17.5
# 2015    18.26
# 2016    17.62
# 2017     17.7
# 2018    18.97
# 2019     18.3
# 2020    21.21
# 2021     20.9
# Name: Armenia, dtype: object

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 6))

for s in ['top', 'right']:
    ax.spines[s].set_visible(False)

plt.plot(df.T["Armenia"].iloc[1:])

plt.title("Unemployment Rate")
plt.xticks(rotation = 60)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate")
plt.grid(axis = "both", ls = "--")

plt.show()

# %% [markdown]
# ## country with the most improving & worst unemployment rate

# %%
tes = (df.loc[:,"2021"]-df.loc[:,"1991"])*100/df.loc[:,"1991"]
tes.sort_values(ascending = False)
# Out:
# Country Name
# Armenia                1206.250000
# Kyrgyz Republic         810.000000
# Belarus                 690.000000
# Azerbaijan              631.111111
# Lithuania               618.181818
#                           ...
# Sri Lanka               -63.233288
# Cuba                    -65.063291
# Qatar                   -67.901235
# Poland                  -74.036980
# Trinidad and Tobago     -74.082073
# Length: 235, dtype: float64

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 6))

for s in ['top', 'right']:
    ax.spines[s].set_visible(False)
    
plt.plot(df.T["Sri Lanka"].iloc[1:], label = "Sri Lanka")
plt.plot(df.T["Cuba"].iloc[1:], label = "Cuba")
plt.plot(df.T["Qatar"].iloc[1:], label = "Qatar")
plt.plot(df.T["Poland"].iloc[1:], label = "Poland")
plt.plot(df.T["Trinidad and Tobago"].iloc[1:], label = "Trinidad and Tobago")
    
plt.title("Countries with the best Development of Unemployment Rate")
plt.xticks(rotation = 60)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate")
plt.grid(axis = "both", ls = "--")

plt.legend(loc = 1)

plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(12, 6))

for s in ['top', 'right']:
    ax.spines[s].set_visible(False)
    
plt.plot(df.T["Armenia"].iloc[1:], label = "Armenia")
plt.plot(df.T["Kyrgyz Republic"].iloc[1:], label = "Kyrgyz Republic")
plt.plot(df.T["Belarus"].iloc[1:], label = "Belarus")
plt.plot(df.T["Azerbaijan"].iloc[1:], label = "Azerbaijan")
plt.plot(df.T["Lithuania"].iloc[1:], label = "Lithuania")
    
plt.title("Countries with the worst Development of Unemployment Rate")
plt.xticks(rotation = 60)
plt.xlabel("Years")
plt.ylabel("Unemployment Rate")
plt.grid(axis = "both", ls = "--")

plt.legend(loc = 1)

plt.show()
